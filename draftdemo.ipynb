# %% [markdown]
# ## DEMO RUN for few products

# %%
# links =["https://phongvu.vn/laptop-lg-gram-2024-16z90s-g-ah76a5--s240802628",
#               "https://phongvu.vn/laptop-yoga-slim-7-14imh9-83cv001vvn-ultra-7-155h-xam--s240300072",
#               "https://phongvu.vn/laptop-msi-stealth-16-mercedes-amg-motorsport-a1vgg-293vn--s240702974",
#               "https://phongvu.vn/laptop-hp-15s-fq5228tu-8u240pa-i3-1215u-xanh--s231002798",
#               "https://phongvu.vn/apple-macbook-pro-16-inch-2023-m3-pro-18gb-512gb-ssd--p534238?sku=231100718",
#               "https://phongvu.vn/laptop-gigabyte-g5-me-51vn263sh-i5-12500h-den--s221002062"]
from scraping import *
import pandas as pd
import time

# Start the timer
start_time = time.time()

# List of links
links = ["https://phongvu.vn/laptop-lg-gram-2024-16z90s-g-ah76a5--s240802628"]

laptop_list = []
for link in links:
    laptop_info = get_laptop_info(link)
    laptop_list.append(laptop_info)

# Convert list of dictionaries to DataFrame
lap_df = pd.DataFrame(laptop_list)

# Save DataFrame to CSV
lap_df.to_csv("laptopdemodata1.csv", header=True, index=False)

# Stop the timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

# Print the time taken for SCRAPING 1 PRODUCT
print(f"Execution time: {execution_time} seconds")
# Out:
# Execution time: 28.31199026107788 seconds

# %%
#lap_df = lap_df.drop('', axis=1)
lap_df.info()
lap_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Product name            6 non-null      object
#  1   Price                   6 non-null      object
#  2                           6 non-null      object
#  3   Thương hiệu             6 non-null      object
#  4   Bảo hành                6 non-null      object
#  5   CPU                     6 non-null      object
#  6   NPU                     3 non-null      object
#  7   Chip đồ họa             5 non-null      object
#  8   Màn hình                6 non-null      object
#  9   Webcam                  5 non-null      object
#  10  Ram                     5 non-null      object
#  11  Lưu trữ                 5 non-null      object
#  12  Cổng kết nối            6 non-null      object
#  13  Âm thanh                3 non-null      object
# ...

# %%
import pandas as pd

# Sample data: List of dictionaries
data = [
    {'Feature1': 1, 'Feature2': 'A', 'Feature3': 0.5},
    {'Feature2': 2, 'Feature1': 'B', 'Feature3': 0.75},
    {'Feature3': 3, 'Feature2': 'C', 'Feature1': 1.0}
]

# Convert list of dictionaries to DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#   Feature1 Feature2  Feature3
# 0        1        A      0.50
# 1        B        2      0.75
# 2      1.0        C      3.00

# %% [markdown]
# ## IMPORT COLLECTED DATA
